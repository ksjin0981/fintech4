# %% [markdown]
# # 다중분류모델개발 후 서비스하기_train

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib

# %%
data = pd.read_csv("./data/wine_train.csv")
data
# Out:
#      와인_종류  알코올_도수  사과산_함량  재_함량  재의_알칼리도  마그네슘_함량  총_페놀_함량  플라보노이드_함량  \
# 0        1   13.76    1.53  2.70     19.5      132     2.95       2.74
# 1        2   12.67    0.98  2.24     18.0       99     2.20       1.94
# 2        1   13.58    1.66  2.36     19.1      106     2.86       3.19
# 3        2   13.86    1.51  2.67     25.0       86     2.95       2.86
# 4        1   13.05    2.05  3.22     25.0      124     2.63       2.68
# ..     ...     ...     ...   ...      ...      ...      ...        ...
# 101      2   12.43    1.53  2.29     21.5       86     2.74       3.15
# 102      3   12.20    3.03  2.32     19.0       96     1.25       0.49
# 103      1   13.51    1.80  2.65     19.0      110     2.35       2.53
# 104      2   12.70    3.87  2.40     23.0      101     2.83       2.55
# 105      2   12.51    1.73  1.98     20.5       85     2.20       1.92
#
#      비플라보노이드_페놀_함량  프로안토시아닌_함량  색_강도    색조  희석_와인의_투과율_OD280_OD315  프롤린_함량
# 0             0.50        1.35  5.40  1.25                    3.00    1235
# 1             0.30        1.46  2.62  1.23                    3.16     450
# 2             0.22        1.95  6.90  1.09                    2.88    1515
# 3             0.21        1.87  3.38  1.36                    3.16     410
# 4             0.47        1.92  3.58  1.13                    3.20     830
# ..             ...         ...   ...   ...                     ...     ...
# 101           0.39        1.77  3.94  0.69                    2.84     352
# 102           0.40        0.73  5.50  0.66                    1.83     510
# 103           0.29        1.54  4.20  1.10                    2.87    1095
# 104           0.43        1.95  2.57  1.19                    3.13     463
# 105           0.32        1.48  2.94  1.04                    3.57     672
#
# [106 rows x 14 columns]

# %%
data['와인_종류'].value_counts()
# Out:
# 와인_종류
# 2    42
# 1    35
# 3    29
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   와인_종류                   106 non-null    int64
#  1   알코올_도수                  106 non-null    float64
#  2   사과산_함량                  106 non-null    float64
#  3   재_함량                    106 non-null    float64
#  4   재의_알칼리도                 106 non-null    float64
#  5   마그네슘_함량                 106 non-null    int64
#  6   총_페놀_함량                 106 non-null    float64
#  7   플라보노이드_함량               106 non-null    float64
#  8   비플라보노이드_페놀_함량           106 non-null    float64
#  9   프로안토시아닌_함량              106 non-null    float64
#  10  색_강도                    106 non-null    float64
#  11  색조                      106 non-null    float64
#  12  희석_와인의_투과율_OD280_OD315  106 non-null    float64
#  13  프롤린_함량                  106 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 11.7 KB

# %%
sns.boxplot(data.iloc[:,2:5])
# Out:
# <Axes: >

# %%
sns.boxplot(data.iloc[:,5:-1])
# Out:
# <Axes: >

# %%
X =data.drop('와인_종류', axis=1)
y = data['와인_종류']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X,y, test_size=0.3, stratify=y, random_state=42)

# %%
from sklearn.preprocessing import RobustScaler

# %%
rs = RobustScaler()
rs_X_train = rs.fit_transform(X_train)
rs_X_valid = rs.transform(X_valid)

# %% [markdown]
# # rs 변수에 있는 RobustScaler를 저장 - joblib

# %%
import joblib

# %%
joblib.dump(rs, "./model/Robust_info.joblib")
# Out:
# ['./model/Robust_info.joblib']

# %%
y_train.unique()
# Out:
# array([3, 2, 1])

# %% [markdown]
# #  y 변수 레이블 인코딩

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
le_y_train = le.fit_transform(y_train)
le_y_valid = le.transform(y_valid)

# %% [markdown]
# # 딥러닝 모델 작성 및 훈련

# %%
from keras.models import Sequential
from keras.layers import Input, Dense, Dropout, BatchNormalization
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
rs_X_train.shape[1]
# Out:
# 13

# %%
len(np.unique(le_y_train))
# Out:
# 3

# %%
model = Sequential()
model.add(Input(shape=(rs_X_train.shape[1],)))
model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.3))
model.add(Dense(64, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.3))
model.add(Dense(32, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.3))
model.add(Dense(len(np.unique(le_y_train)), activation='softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 128)            │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 3)              │            99 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,123 (51.26 KB)
#  Trainable params: 12,675 (49.51 KB)
#  Non-trainable params: 448 (1.75 KB)

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
early_stop = EarlyStopping(patience=100, restore_best_weights=True)
file_path = "./model/red_wine_best_model.keras"
model_save = ModelCheckpoint(filepath=file_path, save_best_only=True)
history = model.fit(rs_X_train,le_y_train,epochs=1000, batch_size=16, validation_data=(rs_X_valid, le_y_valid), callbacks=[early_stop, model_save])
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend(['train', 'valid'])
plt.show()
# Out:
# Epoch 1/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 662ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9375 - val_loss: 0.3063
# Epoch 2/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 5.5822e-04 - val_accuracy: 0.9375 - val_loss: 0.2958
# Epoch 3/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 7.7458e-04 - val_accuracy: 0.9375 - val_loss: 0.2921
# Epoch 4/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9375 - val_loss: 0.2912
# Epoch 5/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9865 - loss: 0.0140 - val_accuracy: 0.9375 - val_loss: 0.2904
# Epoch 6/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 4.5417e-04 - val_accuracy: 0.9375 - val_loss: 0.2832
# Epoch 7/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 5.3658e-04 - val_accuracy: 0.9375 - val_loss: 0.2801
# Epoch 8/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 6.5529e-04 - val_accuracy: 0.9375 - val_loss: 0.2797
# Epoch 9/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9595 - loss: 0.2424 - val_accuracy: 0.9375 - val_loss: 0.2731
# Epoch 10/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9375 - val_loss: 0.2806
# Epoch 11/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 2.3719e-04 - val_accuracy: 0.9375 - val_loss: 0.2841
# Epoch 12/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.9375 - val_loss: 0.2878
# Epoch 13/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9865 - loss: 0.0318 - val_accuracy: 0.9375 - val_loss: 0.2872
# Epoch 14/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9865 - loss: 0.0260 - val_accuracy: 0.9375 - val_loss: 0.2751
# Epoch 15/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9375 - val_loss: 0.2695
# Epoch 16/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 3.0126e-04 - val_accuracy: 0.9375 - val_loss: 0.2696
# Epoch 17/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9865 - loss: 0.0173 - val_accuracy: 0.9375 - val_loss: 0.2784
# Epoch 18/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 1.0990e-04 - val_accuracy: 0.9375 - val_loss: 0.2866
# Epoch 19/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.9375 - val_loss: 0.2914
# Epoch 20/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 9.4750e-04 - val_accuracy: 0.9375 - val_loss: 0.2952
# Epoch 21/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9375 - val_loss: 0.3039
# Epoch 22/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 0.9375 - val_loss: 0.3099
# Epoch 23/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 0.9375 - val_loss: 0.3054
# Epoch 24/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9375 - val_loss: 0.3017
# Epoch 25/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 0.9375 - val_loss: 0.2995
# Epoch 26/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.9375 - val_loss: 0.3022
# Epoch 27/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 5.0110e-04 - val_accuracy: 0.9375 - val_loss: 0.3009
# Epoch 28/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.9375 - val_loss: 0.3010
# Epoch 29/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9375 - val_loss: 0.3005
# Epoch 30/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9375 - val_loss: 0.3015
# Epoch 31/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 2.3381e-04 - val_accuracy: 0.9375 - val_loss: 0.3025
# Epoch 32/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9375 - val_loss: 0.3013
# Epoch 33/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9375 - val_loss: 0.3039
# Epoch 34/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9375 - val_loss: 0.3020
# Epoch 35/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 4.0546e-04 - val_accuracy: 0.9375 - val_loss: 0.3037
# Epoch 36/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 7.5683e-04 - val_accuracy: 0.9375 - val_loss: 0.3064
# Epoch 37/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 1.2748e-04 - val_accuracy: 0.9375 - val_loss: 0.3065
# Epoch 38/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 1.3519e-04 - val_accuracy: 0.9375 - val_loss: 0.3068
# Epoch 39/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.9375 - val_loss: 0.3085
# Epoch 40/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9375 - val_loss: 0.3157
# Epoch 41/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9375 - val_loss: 0.3209
# Epoch 42/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9375 - val_loss: 0.3186
# Epoch 43/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.9375 - val_loss: 0.3231
# Epoch 44/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 8.5228e-04 - val_accuracy: 0.9375 - val_loss: 0.3246
# Epoch 45/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 7.2906e-04 - val_accuracy: 0.9375 - val_loss: 0.3247
# Epoch 46/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9375 - val_loss: 0.3261
# Epoch 47/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 8.9553e-05 - val_accuracy: 0.9375 - val_loss: 0.3280
# Epoch 48/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.9375 - val_loss: 0.3233
# Epoch 49/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.9375 - val_loss: 0.3049
# Epoch 50/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 2.7404e-04 - val_accuracy: 0.9375 - val_loss: 0.2878
# Epoch 51/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9730 - loss: 0.0389 - val_accuracy: 0.9375 - val_loss: 0.2582
# Epoch 52/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 1.8568e-04 - val_accuracy: 0.9375 - val_loss: 0.2312
# Epoch 53/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.9375 - val_loss: 0.2221
# Epoch 54/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.9375 - val_loss: 0.2118
# Epoch 55/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.9375 - val_loss: 0.1660
# Epoch 56/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 7.3199e-04 - val_accuracy: 0.9375 - val_loss: 0.1340
# Epoch 57/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.9375 - val_loss: 0.1174
# Epoch 58/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.9375 - val_loss: 0.1120
# Epoch 59/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 8.6717e-04 - val_accuracy: 0.9375 - val_loss: 0.1102
# Epoch 60/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 7.7946e-04 - val_accuracy: 0.9375 - val_loss: 0.1079
# Epoch 61/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9865 - loss: 0.0165 - val_accuracy: 0.9375 - val_loss: 0.1477
# Epoch 62/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 0.9375 - val_loss: 0.1751
# Epoch 63/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 5.3947e-04 - val_accuracy: 0.9375 - val_loss: 0.1732
# Epoch 64/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 6.5209e-04 - val_accuracy: 0.9375 - val_loss: 0.1722
# Epoch 65/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 5.2939e-04 - val_accuracy: 0.9375 - val_loss: 0.1710
# Epoch 66/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.9375 - val_loss: 0.1747
# Epoch 67/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9595 - loss: 0.1640 - val_accuracy: 0.9375 - val_loss: 0.1934
# Epoch 68/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9375 - val_loss: 0.2603
# Epoch 69/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9375 - val_loss: 0.3045
# Epoch 70/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 3.0605e-04 - val_accuracy: 0.9375 - val_loss: 0.3318
# Epoch 71/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9375 - val_loss: 0.3485
# Epoch 72/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9375 - val_loss: 0.3532
# Epoch 73/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 1.9319e-04 - val_accuracy: 0.9375 - val_loss: 0.3571
# Epoch 74/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9865 - loss: 0.0497 - val_accuracy: 0.9375 - val_loss: 0.3583
# Epoch 75/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 0.9375 - val_loss: 0.3559
# Epoch 76/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 0.9375 - val_loss: 0.3532
# Epoch 77/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9865 - loss: 0.0530 - val_accuracy: 0.9375 - val_loss: 0.3614
# Epoch 78/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9865 - loss: 0.0278 - val_accuracy: 0.9375 - val_loss: 0.3907
# Epoch 79/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9375 - val_loss: 0.4141
# Epoch 80/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9865 - loss: 0.0880 - val_accuracy: 0.9375 - val_loss: 0.4226
# Epoch 81/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9375 - val_loss: 0.4254
# Epoch 82/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 4.7895e-04 - val_accuracy: 0.9375 - val_loss: 0.4219
# Epoch 83/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 3.9153e-04 - val_accuracy: 0.9375 - val_loss: 0.4186
# Epoch 84/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 6.9778e-04 - val_accuracy: 0.9375 - val_loss: 0.4179
# Epoch 85/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 5.0224e-04 - val_accuracy: 0.9375 - val_loss: 0.4160
# Epoch 86/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9595 - loss: 0.2389 - val_accuracy: 0.9375 - val_loss: 0.4219
# Epoch 87/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 3.9762e-04 - val_accuracy: 0.9375 - val_loss: 0.4207
# Epoch 88/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 6.8436e-04 - val_accuracy: 0.9375 - val_loss: 0.4216
# Epoch 89/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 3.3079e-04 - val_accuracy: 0.9375 - val_loss: 0.4182
# Epoch 90/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9375 - val_loss: 0.4172
# Epoch 91/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9730 - loss: 0.1124 - val_accuracy: 0.9375 - val_loss: 0.4139
# Epoch 92/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.9375 - val_loss: 0.4092
# Epoch 93/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 5.1242e-04 - val_accuracy: 0.9375 - val_loss: 0.4045
# Epoch 94/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 7.7187e-04 - val_accuracy: 0.9375 - val_loss: 0.3988
# Epoch 95/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.9375 - val_loss: 0.3999
# Epoch 96/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 1.4084e-04 - val_accuracy: 0.9375 - val_loss: 0.3991
# Epoch 97/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.9375 - val_loss: 0.3976
# Epoch 98/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.9375 - val_loss: 0.3977
# Epoch 99/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 4.6881e-04 - val_accuracy: 0.9375 - val_loss: 0.3968
# Epoch 100/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 6.1505e-04 - val_accuracy: 0.9375 - val_loss: 0.3962
# Epoch 101/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 0.0079 - val_accuracy: 0.9375 - val_loss: 0.3902
# Epoch 102/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.9375 - val_loss: 0.3871
# Epoch 103/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.9375 - val_loss: 0.3831
# Epoch 104/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 6.9020e-04 - val_accuracy: 0.9375 - val_loss: 0.3792
# Epoch 105/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.9375 - val_loss: 0.3768
# Epoch 106/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9375 - val_loss: 0.3765
# Epoch 107/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 6.5956e-04 - val_accuracy: 0.9375 - val_loss: 0.3810
# Epoch 108/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9375 - val_loss: 0.3826
# Epoch 109/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 2.4804e-04 - val_accuracy: 0.9375 - val_loss: 0.3856
# Epoch 110/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 0.9375 - val_loss: 0.3833
# Epoch 111/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9375 - val_loss: 0.3775
# Epoch 112/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 1.5622e-04 - val_accuracy: 0.9375 - val_loss: 0.3727
# Epoch 113/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9375 - val_loss: 0.3706
# Epoch 114/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 3.0464e-04 - val_accuracy: 0.9375 - val_loss: 0.3692
# Epoch 115/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 8.0199e-04 - val_accuracy: 0.9375 - val_loss: 0.3674
# Epoch 116/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 4.6381e-04 - val_accuracy: 0.9375 - val_loss: 0.3700
# Epoch 117/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 7.1321e-05 - val_accuracy: 0.9375 - val_loss: 0.3682
# Epoch 118/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9865 - loss: 0.0186 - val_accuracy: 0.9375 - val_loss: 0.3641
# Epoch 119/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 5.2681e-04 - val_accuracy: 0.9375 - val_loss: 0.3552
# Epoch 120/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0095 - val_accuracy: 0.9375 - val_loss: 0.3491
# Epoch 121/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9375 - val_loss: 0.3418
# Epoch 122/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9865 - loss: 0.0345 - val_accuracy: 0.9375 - val_loss: 0.3356
# Epoch 123/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.9375 - val_loss: 0.3349
# Epoch 124/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 1.8809e-04 - val_accuracy: 0.9375 - val_loss: 0.3349
# Epoch 125/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9865 - loss: 0.0402 - val_accuracy: 0.9375 - val_loss: 0.3031
# Epoch 126/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0172 - val_accuracy: 0.9688 - val_loss: 0.2875
# Epoch 127/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 7.5735e-04 - val_accuracy: 0.9688 - val_loss: 0.2758
# Epoch 128/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 2.1322e-04 - val_accuracy: 0.9688 - val_loss: 0.2696
# Epoch 129/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9688 - val_loss: 0.2661
# Epoch 130/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 5.8011e-04 - val_accuracy: 0.9688 - val_loss: 0.2624
# Epoch 131/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 2.6726e-04 - val_accuracy: 0.9688 - val_loss: 0.2601
# Epoch 132/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9730 - loss: 0.0369 - val_accuracy: 0.9688 - val_loss: 0.2623
# Epoch 133/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 4.5701e-04 - val_accuracy: 0.9688 - val_loss: 0.2818
# Epoch 134/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 6.9521e-04 - val_accuracy: 0.9375 - val_loss: 0.2991
# Epoch 135/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9375 - val_loss: 0.3098
# Epoch 136/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0113 - val_accuracy: 0.9375 - val_loss: 0.3159
# Epoch 137/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 2.3917e-04 - val_accuracy: 0.9375 - val_loss: 0.3143
# Epoch 138/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9375 - val_loss: 0.3167
# Epoch 139/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 4.0409e-04 - val_accuracy: 0.9375 - val_loss: 0.3173
# Epoch 140/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.9375 - val_loss: 0.3171
# Epoch 141/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 1.3819e-04 - val_accuracy: 0.9375 - val_loss: 0.3175
# Epoch 142/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9730 - loss: 0.0841 - val_accuracy: 0.9375 - val_loss: 0.3140
# Epoch 143/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 4.9407e-04 - val_accuracy: 0.9375 - val_loss: 0.3192
# Epoch 144/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.9375 - val_loss: 0.3261
# Epoch 145/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 5.2150e-04 - val_accuracy: 0.9375 - val_loss: 0.3307
# Epoch 146/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 2.9753e-04 - val_accuracy: 0.9375 - val_loss: 0.3339
# Epoch 147/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 3.0799e-04 - val_accuracy: 0.9375 - val_loss: 0.3363
# Epoch 148/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 7.9374e-04 - val_accuracy: 0.9375 - val_loss: 0.3352
# Epoch 149/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9375 - val_loss: 0.3348
# Epoch 150/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 4.1920e-04 - val_accuracy: 0.9375 - val_loss: 0.3343
# Epoch 151/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9865 - loss: 0.0182 - val_accuracy: 0.9375 - val_loss: 0.3146
# Epoch 152/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9865 - loss: 0.0372 - val_accuracy: 0.9375 - val_loss: 0.3009
# Epoch 153/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 5.9384e-04 - val_accuracy: 0.9375 - val_loss: 0.2944
# Epoch 154/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 2.5018e-04 - val_accuracy: 0.9375 - val_loss: 0.2917
# Epoch 155/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 5.7276e-04 - val_accuracy: 0.9375 - val_loss: 0.2894
# Epoch 156/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 8.2619e-04 - val_accuracy: 0.9375 - val_loss: 0.2859
# Epoch 157/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.9375 - val_loss: 0.2833
# Epoch 158/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9375 - val_loss: 0.2842
# Epoch 159/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 2.8283e-04 - val_accuracy: 0.9375 - val_loss: 0.2841
# Epoch 160/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.9375 - val_loss: 0.2867

# %% [markdown]
# # 머신러닝 모델 저장하기

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold

# %%
scv = StratifiedKFold(shuffle=True, random_state=42)
params = dict(max_depth=[3,6,9,12,15], n_estimators=[100, 300, 500, 1000, 1500, 2000])
model = RandomForestClassifier(random_state=42, class_weight='balanced')
randcv = RandomizedSearchCV(n_iter=100, estimator=model, param_distributions=params, cv=scv, random_state=42, n_jobs=-1)
randcv.fit(X_train, y_train)
print("best_estimator: ", randcv.best_estimator_)
print("best_params: ", randcv.best_params_)
val_pred2 = randcv.predict(X_valid)
print(classification_report(y_valid, val_pred2))
# Out:
# /home/ksjin/miniforge3/envs/tf/lib/python3.12/site-packages/sklearn/model_selection/_search.py:324: UserWarning: The total space of parameters 30 is smaller than n_iter=100. Running 30 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# best_estimator:  RandomForestClassifier(class_weight='balanced', max_depth=3, random_state=42)
# best_params:  {'n_estimators': 100, 'max_depth': 3}
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        10
#            2       1.00      0.92      0.96        13
#            3       0.90      1.00      0.95         9
#
#     accuracy                           0.97        32
#    macro avg       0.97      0.97      0.97        32
# weighted avg       0.97      0.97      0.97        32

# %%
joblib.dump(randcv, "./model/rfc_model.joblib")
# Out:
# ['./model/rfc_model.joblib']
