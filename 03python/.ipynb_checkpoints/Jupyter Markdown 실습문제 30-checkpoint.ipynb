# %% [markdown]
# # 내 첫 번째 노트북

# %% [markdown]
# ## 실습 목표

# %% [markdown]
# 데이터 분석은 질문에서 시작한다.
#
# 좋은 질문이 좋은 결과를 만든다.

# %% [markdown]
# 첫 줄
# 둘째 줄

# %% [markdown]
# **중요**

# %% [markdown]
# *주의*

# %% [markdown]
# ***핵심***

# %% [markdown]
# 변수는 `x = 10` 으로 만든다.

# %% [markdown]
# - 사과
# - 바나나
# - 포도

# %% [markdown]
# 1. 수집
# 2. 정제
# 3. 학습

# %% [markdown]
# - 과일
#   - 사과
#   - 바나나

# %% [markdown]
# > 측정할 수 없으면 개선할 수 없다.

# %% [markdown]
# ---

# %% [markdown]
# [OpenAI](https://www.openai.com)

# %% [markdown]
# ![sample](images/sample.png)

# %% [markdown]
# | 이름 | 나이 |
# |---|---|
# | 철수 | 20 |
# | 영희 | 21 |

# %% [markdown]
# - [ ] 밥
# - [x] 청소
# - [x] 운동

# %% [markdown]
# ```python
# print("hello")
# ```

# %% [markdown]
# ```sql
# SELECT * FROM LIMIT 5;
# ```

# %% [markdown]
# “직선은 $y = ax + b$ 로 표현한다.”

# %% [markdown]
# $$
# \sum_{i=1}^{n} x_i
# $$

# %% [markdown]
# > **중요**한 것은 꾸준함이다.

# %% [markdown]
# [문서](https://example.com)와 ` README.md`

# %% [markdown]
# - [ ] 데이터 수집
# - [x] 전처리
# - [x] 모델 학습

# %% [markdown]
# |항목|값|
# |:---|---:|
# |정확도|0.93|
# |손실|0.12|

# %% [markdown]
# ## 제목 2: "요약"
# > 결과는 재현 가능해야 한다."]
# - [x]데이터 저장
# - [ ] 리포트 작성
# ---
# $ E = mc^2 $
