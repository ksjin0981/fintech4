# %% [markdown]
# # 주피터 노트북 사용법\<h1>
# * 하위목록1
#   * 하위목록2
# ## 주피터 노트북 사용법\<h2>
# ### 주피터 노트북 사용법\<h3>
# #### 주피터 노트북 사용법\<h4>
# ##### 주피터 노트북 사용법\<h5>
# ###### 주피터 노트북 사용법\<h6>

# %%
a+b

# %%
a+b

# %% [markdown]
# # Jupyter Notebook 마크다운 문법

# %% [markdown]
# ## 제목
# * 제목은 \#의 개수에 따라 제목 크기가 달라진다.

# %% [markdown]
# # 제목 1
# ## 제목 2
# ### 제목 3
# #### 제목 4

# %% [markdown]
# # 문단 & 줄바꿈

# %% [markdown]
# ### 문단
# * 한줄을 비우면 새로운 문단이 된다.

# %% [markdown]
# 이것은 첫 번재 문단이다.
#
# 이것은 두번째 문단이다.

# %% [markdown]
# ## 줄바꿈
# * 문장 끝에 공백 2칸을 넣고 enter
# * 문장 끝에 \<br> 태그 넣기

# %% [markdown]
# 첫 줄입니다.
# 두 번째 줄입니다.

# %% [markdown]
# ## 강조
# * 굵게 \**
# * 기울임\*
# * 굵고 기울임 \***

# %% [markdown]
# **굵은 글씨**
# *기울임 글씨*
# ***굵고 기울인 글씨***

# %% [markdown]
# # 목록

# %% [markdown]
# ### 순서 없는 목록 \-,\*

# %% [markdown]
# - 사과
# - 바나나
# - 포도

# %% [markdown]
# ### 순서 있는 목록

# %% [markdown]
# 1. 데이터 수집
# 2. 데이터 전처리
# 3. 모델 학습
# 4. 결과 분석

# %% [markdown]
# ### 중첩 목록

# %% [markdown]
# - 과일
#   - 사과
#   - 바나나
# - 채소
#   - 당근

# %% [markdown]
# ## 코드

# %% [markdown]
# ### 인라인 코드
# * 문장 중간에 코드를 표시할 때 백틱 1개 사용
# 변수는 `X=10` 처럼 정의한다.

# %% [markdown]
# ### 코드 블록
# * 여러 줄 코드를 표시할 때 백틱 3개 사용
# * 언어 이름을 쓰면 문법 강조가 적용됨

# %% [markdown]
# ```python
# for i in range(5):
#     print(i)
# ```

# %% [markdown]
# ## 인용문 \ >

# %% [markdown]
# > 데이터 분석에서 가장 중요한 것은 질문이다.

# %% [markdown]
# ## 구분선 ---

# %% [markdown]
# ---

# %% [markdown]
# ## 링크
# * \[텍스트](URL)

# %% [markdown]
# [구글 바로가기](https://www.google.com)

# %% [markdown]
# ## 이미지 넣기
# * \!\[이미지 예시](https://image.utoimage.com/preview/cp872722/2022/12/202212008462_500.jpg)

# %% [markdown]
# ![shutterstock_1844153299-1024x683-1.png](attachment:shutterstock_1844153299-1024x683-1.png)

# %% [markdown]
# ## 표
# ```
# | 이름 | 나이 | 전공 |
# |---|---|---|
# | 철수 | 20 | 컴퓨터 |
# | 영희 | 21 | 수학 |

# %% [markdown]
# | 이름 | 나이 | 전공 |
# |---|---|---|
# | 철수 | 20 | 컴퓨터 |
# | 영희 | 21 | 수학 |

# %% [markdown]
# ### 정렬
# | 이름 | 나이 | 전공 |
# |:---|:---:|---:|
# |   철수철수   |   20   |   컴퓨터공학   |
# |   영희영희   |   21   |   수학수학   |

# %% [markdown]
# ## 체크박스
# 체크박스는 - [ ], 체크 완료는 - [x]

# %% [markdown]
# - [x] 데이터 수집
# - [ ] 전처리
# - [ ] 모델 학습

# %% [markdown]
#  ## 수식 (LaTex)
#  ```$y = ax + b$```
#
#
#  $y = ax + b$

# %% [markdown]
# ### 블록 수식
# ```$$
# \sum_{i=1}^{n} x_i
# $$```
#
# $$
# \sum_{i=1}^{n} x_i
# $$
