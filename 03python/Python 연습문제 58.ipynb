# %% [markdown]
# 4.문제: print()를 사용하여 10, 20, 30을 한 줄에 공백 없이 출력하세요.

# %%
print(10,20,30,sep="")
# Out:
# 102030

# %% [markdown]
# 6.문제: 두 개의 print() 문을 사용하되, 한 줄에 출력하세요.

# %%
print("Hello", end=" ")
print("Python")
# Out:
# Hello Python

# %% [markdown]
# 8.문제: print()를 사용하여 50 - 15의 결과를 출력하세요.
#
# 결과 값: 50 - 15:35

# %%
print('50 - 15:',50-15, sep="")
# Out:
# 50 - 15:35

# %% [markdown]
# 11. 문제: print()를 사용하여 20 을 3으로 나눈 몫을 출력하세요.

# %%
print(20//3)
# Out:
# 6

# %% [markdown]
# 12.문제: print()를 사용하여 20을 3으로 나눈 나머지를 출력하세요.

# %%
print(20%3)
# Out:
# 2

# %% [markdown]
# 13.문제: print()를 사용하여 2의 5제곱 결과를 출력하세요.

# %%
print(2**5)
# Out:
# 32

# %% [markdown]
# 19.문제: print()를 사용하여 100을 3으로 나눈 결과를 정수형으로 출력하세요.

# %%
print(int(100/3))
# Out:
# 33

# %% [markdown]
# 21.문제: print()를 사용하여 1부터 10까지의 합을 출력하세요.

# %%
hap=0
for i in range(1,11):
    hap=hap+i

print(hap)
# Out:
# 55

# %% [markdown]
# 24.문제: print()를 사용하여 숫자 10을 문자열과 함께 출력하세요.
# 결과 값:The number is 10

# %%
print("The number is", 10)
# Out:
# The number is 10

# %%
a=10
b=3.14
c="Python"
d=True

# %% [markdown]
# 32.문제: 문자열 "Python"에서 첫 번째 문자를 출력하세요.

# %%
"Python"[0]
# Out:
# 'P'

# %% [markdown]
# 34.문제: 문자열 "Python Programming"에서 "Programming"만 출력하세요.

# %%
"Python Programming"[7:19]
# Out:
# 'Programming'

# %%
numbers=[1,2,3,4,5]

# %% [markdown]
# 40.문제: 리스트 numbers에 숫자 6을 추가하고 출력하세요.

# %%
numbers.append(6)
print(numbers)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
nested_list = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
nested_tutple = ((1,2), (3,4,5), (6,7,8,9))

# %%
person = {"name": "Alice", "info": {"age": 25, "city": "Seoul"}}

# %% [markdown]
# 47.문제: person 딕셔너리에서 "age" 값을 출력하세요.

# %%
person["info"]["age"]
# Out:
# 25

# %%
data = {'info' : [{'name': 'Alice', 'scores' : (95, 88, 92)},
                  {'name': 'Bob', 'scores' : (78, 85, 89)}],
        'extra': {'hobbies' : ['leading', 'coding'],
                  'location' : ('Seoul', 'Busan')}}

# %% [markdown]
# 49.문제: data에서 "Alice"의 첫 번째 점수를 출력하세요.

# %%
data['info'][0]['scores'][0]
# Out:
# 95

# %% [markdown]
# 54.문제: data에서 "Bob"의 평균 점수를 출력하세요. ???

# %%
Bob_scores=data['info'][1]['scores']
print(Bob_scores)
# Out:
# (78, 85, 89)

# %% [markdown]
# 55.문제: data에 새로운 키 "school": "XYZ High"를 추가하고 출력하세요.

# %%
data['school']='XYZ High'
print(data)
# Out:
# {'info': [{'name': 'Alice', 'scores': (95, 88, 92)}, {'name': 'Bob', 'scores': (78, 85, 89)}], 'extra': {'hobbies': ['leading', 'coding'], 'location': ('Seoul', 'Busan')}, 'school': 'XYZ High'}

# %% [markdown]
# 56.문제: data["extra"]["hobbies"]에 "gaming"을 추가하고 출력하세요.

# %%
data['extra']['hobbies'].append('gaming')
print(data)
# Out:
# {'info': [{'name': 'Alice', 'scores': (95, 88, 92)}, {'name': 'Bob', 'scores': (78, 85, 89)}], 'extra': {'hobbies': ['leading', 'coding', 'gaming'], 'location': ('Seoul', 'Busan')}, 'school': 'XYZ High'}

# %% [markdown]
# 57.문제: data에서 "Alice"의 두 번째 점수를 "90"으로 변경하고 출력하세요.

# %%
data['info'][0]['scores']=(95, 90, 92)

# %%
print(data)
# Out:
# {'info': [{'name': 'Alice', 'scores': (95, 90, 92)}, {'name': 'Bob', 'scores': (78, 85, 89)}], 'extra': {'hobbies': ['leading', 'coding', 'gaming'], 'location': ('Seoul', 'Busan')}, 'school': 'XYZ High'}

# %%
data['info'][1]['scores'][0]
# Out:
# 78
