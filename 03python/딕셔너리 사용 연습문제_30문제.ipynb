# %%
# 1
empty_dict={}
print(empty_dict, type(empty_dict))
# Out:
# {} <class 'dict'>

# %%
# 2
person = {"name": "Alice", "age": 25, "city": "Seoul"}
person
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Seoul'}

# %%
# 2 답안
person=dict(name="Alice", age=25, city='Seoul')
person
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Seoul'}

# %%
# 3
person['name']
# Out:
# 'Alice'

# %%
# 4 
person['age']
# Out:
# 25

# %%
# 5
person["job"]="Engineer"
person
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Seoul', 'job': 'Engineer'}

# %%
# 6
person["city"]='Busan'
person
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Busan', 'job': 'Engineer'}

# %%
# 7
del person['age']
person
# Out:
# {'name': 'Alice', 'city': 'Busan', 'job': 'Engineer'}

# %%
# 8
person.keys()
# Out:
# dict_keys(['name', 'city', 'job'])

# %%
# 9
person.values()
# Out:
# dict_values(['Alice', 'Busan', 'Engineer'])

# %%
# 10
person.items()
# Out:
# dict_items([('name', 'Alice'), ('city', 'Busan'), ('job', 'Engineer')])

# %%
# 11
person.get('email', False)
# Out:
# False

# %%
# 11 답안
'email' in person
# Out:
# False

# %%
# 12
del person['job']
person
# Out:
# {'name': 'Alice', 'city': 'Busan'}

# %%
# 13 딕셔너리 초기화 함수 .clear()
person.clear()
person
# Out:
# {}

# %%
# 14
student={"name": "Bob",
 "grades": {"math": 85, "science": 90, "history": 80}
}

# %%
# 15
student['grades']['science']
# Out:
# 90

# %%
# 16
student['grades']['english']=95
student
# Out:
# {'name': 'Bob',
#  'grades': {'math': 85, 'science': 90, 'history': 80, 'english': 95}}

# %%
# 17
student['grades']['math']=88
student
# Out:
# {'name': 'Bob',
#  'grades': {'math': 88, 'science': 90, 'history': 80, 'english': 95}}

# %%
# 18
del student['grades']['history']
student
# Out:
# {'name': 'Bob', 'grades': {'math': 88, 'science': 90, 'english': 95}}

# %%
# 19
student.setdefault('total', student['grades']['math']+student['grades']['science']
                   +student['grades']['english'])
student
# Out:
# {'name': 'Bob',
#  'grades': {'math': 88, 'science': 90, 'english': 95},
#  'total': 273}

# %%
# 20
student['grades'].update(english=100, history=80)
student2=student
print(student2)
# Out:
# {'name': 'Bob', 'grades': {'math': 88, 'science': 90, 'english': 100, 'history': 80}, 'total': 273}

# %%
# 21
courses=dict(programming={'python': 50, 'java': 30, 'Cpp': 20}, 
            design={'Photoshop': 25, 'Illustrator': 15})
courses
# Out:
# {'programming': {'python': 50, 'java': 30, 'Cpp': 20},
#  'design': {'Photoshop': 25, 'Illustrator': 15}}

# %%
# 22
print(courses['programming']['python'])
# Out:
# 50

# %%
# 23
courses['programming']['Cpp']=25
courses
# Out:
# {'programming': {'python': 50, 'java': 30, 'Cpp': 25},
#  'design': {'Photoshop': 25, 'Illustrator': 15}}

# %%
# 24
del courses['design']['Photoshop']
courses
# Out:
# {'programming': {'python': 50, 'java': 30, 'Cpp': 25},
#  'design': {'Illustrator': 15}}

# %%
# 25
courses['programming']['JavaScript']=40
courses
# Out:
# {'programming': {'python': 50, 'java': 30, 'Cpp': 25, 'JavaScript': 40},
#  'design': {'Illustrator': 15}}

# %%
# 26 *중요 list로 변환한 후 더해야지 !
a=list(courses['programming'].keys())

# %%
b=list(courses['design'].keys())

# %%
a+b
# Out:
# ['python', 'java', 'Cpp', 'JavaScript', 'Illustrator']

# %%
# 27
dict(courses['design'].items())
# Out:
# {'Illustrator': 15}

# %%
# 28
del courses['design']
courses
# Out:
# {'programming': {'python': 50, 'java': 30, 'Cpp': 25, 'JavaScript': 40}}

# %%
# 29
'programming' in courses
# Out:
# True

# %%
# 30
courses.get('design', 'design key 없음')
# Out:
# 'design key 없음'
